# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\MAHE'

# %%
movies=pd.read_csv(r"E:\NEXT\Green\Data science\Data sets\movies.csv")

# %%
movies.head()
# Out:
#                                  Film    Genre            Lead Studio  \
# 0          Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                     Youth in Revolt   Comedy  The Weinstein Company
# 2  You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                        When in Rome   Comedy                 Disney
# 4               What Happens in Vegas   Comedy                    Fox
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010
# 2                35       1.211818                 43         $26.66   2010
# 3                44       0.000000                 15         $43.04   2010
# 4                72       6.267647                 28        $219.37   2008

# %%
del movies['Lead Studio']

# %%
del movies['Worldwide Gross']

# %%
movies.head()
# Out:
#                                  Film    Genre  Audience score %  \
# 0          Zack and Miri Make a Porno  Romance                70
# 1                     Youth in Revolt   Comedy                52
# 2  You Will Meet a Tall Dark Stranger   Comedy                35
# 3                        When in Rome   Comedy                44
# 4               What Happens in Vegas   Comedy                72
#
#    Profitability  Rotten Tomatoes %  Year
# 0       1.747542                 64  2008
# 1       1.090000                 68  2010
# 2       1.211818                 43  2010
# 3       0.000000                 15  2010
# 4       6.267647                 28  2008

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               77 non-null     object
#  1   Genre              77 non-null     object
#  2   Audience score %   77 non-null     int64
#  3   Profitability      77 non-null     float64
#  4   Rotten Tomatoes %  77 non-null     int64
#  5   Year               77 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 3.7+ KB

# %%
movies.columns=['film','genre','aud_score','profitability','critiq_score','year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   film           77 non-null     object
#  1   genre          77 non-null     object
#  2   aud_score      77 non-null     int64
#  3   profitability  77 non-null     float64
#  4   critiq_score   77 non-null     int64
#  5   year           77 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 3.7+ KB

# %%
movies.film=movies.film.astype('category')
movies.genre=movies.genre.astype('category')
movies.year=movies.year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   film           77 non-null     category
#  1   genre          77 non-null     category
#  2   aud_score      77 non-null     int64
#  3   profitability  77 non-null     float64
#  4   critiq_score   77 non-null     int64
#  5   year           77 non-null     category
# dtypes: category(3), float64(1), int64(2)
# memory usage: 5.4 KB

# %%
movies.describe()
# Out:
#        aud_score  profitability  critiq_score
# count  77.000000      77.000000     77.000000
# mean   63.727273       4.599483     46.701299
# std    13.657113       8.031990     26.095001
# min    35.000000       0.000000      3.000000
# 25%    52.000000       1.751351     26.000000
# 50%    64.000000       2.642353     45.000000
# 75%    76.000000       5.103117     64.000000
# max    89.000000      66.934000     96.000000

# %%
movies.corr()
# Out:
#                aud_score  profitability  critiq_score
# aud_score       1.000000       0.066278      0.608333
# profitability   0.066278       1.000000      0.042428
# critiq_score    0.608333       0.042428      1.000000

# %%
j=sns.jointplot(data=movies, x='critiq_score', y='aud_score', kind='reg')

# %%
m1=sns.distplot(movies.aud_score)

# %%
m2=sns.distplot(movies.critiq_score)

# %%
sns.set_style('darkgrid')

# %%
m2=sns.distplot(movies.critiq_score, bins=20)

# %%
m3=plt.hist(movies.critiq_score, bins=20)

# %%
vis1=sns.lmplot(data=movies, x='critiq_score', y='aud_score', fit_reg=True)

# %%
vis1=sns.lmplot(data=movies, x='critiq_score', y='aud_score', fit_reg=True, hue='genre')

# %%
kde1=sns.kdeplot(movies.critiq_score,movies.aud_score)

# %%
kde2=sns.kdeplot(movies.critiq_score,movies.aud_score, shade=False,shade_lowest=True,cmap='Reds')

# %%
kde3=sns.kdeplot(movies.critiq_score,movies.aud_score, shade=True,shade_lowest=False,cmap='Reds')

# %%
kde4=sns.kdeplot(movies.critiq_score,movies.aud_score,shade_lowest=False,cmap='Greens_r')

# %%
sns.set_style('dark')
kde5=sns.kdeplot(movies.critiq_score,movies.aud_score,shade_lowest=False)

# %%
f, ax = plt.subplots(1,2,figsize=(10,4))

# %%
f, axes = plt.subplots(1,2,figsize=(10,4))
kde5=sns.kdeplot(movies.critiq_score,movies.aud_score,shade_lowest=False, ax=axes[0])
kde3=sns.kdeplot(movies.critiq_score,movies.aud_score, shade=True,shade_lowest=False,cmap='Reds', ax=axes[1])

# %%
movies
# Out:
#                                   film    genre  aud_score  profitability  \
# 0           Zack and Miri Make a Porno  Romance         70       1.747542
# 1                      Youth in Revolt   Comedy         52       1.090000
# 2   You Will Meet a Tall Dark Stranger   Comedy         35       1.211818
# 3                         When in Rome   Comedy         44       0.000000
# 4                What Happens in Vegas   Comedy         72       6.267647
# ..                                 ...      ...        ...            ...
# 72                 Across the Universe  romance         84       0.652603
# 73                       A Serious Man    Drama         64       4.382857
# 74                  A Dangerous Method    Drama         89       0.448645
# 75                          27 Dresses   Comedy         71       5.343622
# 76                (500) Days of Summer   comedy         81       8.096000
#
#     critiq_score  year
# 0             64  2008
# 1             68  2010
# ...

# %%
w= sns.boxplot(data=movies, x='genre',y='critiq_score')

# %%
v= sns.violinplot(data=movies, x='genre',y='critiq_score')

# %%
w1= sns.boxplot(data=movies[movies.genre=='Drama'], x='year',y='aud_score')

# %%
g=sns.FacetGrid(movies,row='genre',col='year',hue='genre')

# %%
plt.scatter(movies.critiq_score,movies.aud_score)

# %%
g=sns.FacetGrid(movies,row='genre',col='year',hue='genre')
g=g.map(plt.scatter,'critiq_score','aud_score')

# %%
g1=sns.FacetGrid(movies,row='genre',col='year',hue='genre')
g1=g1.map(plt.hist,'aud_score')

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots(2,2, figsize = (15,15))

kde7=sns.kdeplot(movies.critiq_score,movies.aud_score, shade=True,shade_lowest=False,cmap='cool',ax=axes[0,0])

kde8=sns.kdeplot(movies.critiq_score,movies.aud_score, shade=True,shade_lowest=False,cmap='inferno', ax=axes[0,1])

v= sns.violinplot(data=movies, x='genre',y='critiq_score', ax=axes[1,0])

kde9=sns.kdeplot(movies.critiq_score,movies.aud_score, shade=True,shade_lowest=False,cmap='Reds', ax=axes[1,1])
